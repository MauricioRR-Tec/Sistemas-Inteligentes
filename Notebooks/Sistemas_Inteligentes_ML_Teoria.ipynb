# %% [markdown]
# <h1><center>Introducción a Inteligencia Artificial - Teoría P2</center></h1>
#
# ---
#
# <h3><center>Notebook Teórica</center></h3>
#
# ---
#
#
# Esta notebook cuenta con la teoría detrás de los Módulos 3 y 4 de la materia. Espero que sirva como base importante de la materia.
#
# Además, como ya se mencionó en la Parte 1, contará con otra **notebook** con ejercicios complementarios para tratar de entender mejor.
#
# La notebook de ejercicios correspondiente a esta parte teórica se llama "**ML-Notebook de Ejercicios Parte 2**". A diferencia de la Parte 1 de ejercicios, contará con ejercicios de diversas fuentes, pero también se recomienda tener a la mano el repositorio de códigos de [AIMA](https://github.com/aimacode/aima-python)
#
# <img src=https://i.imgflip.com/4g7teg.jpg width="300"/>
#
# <a id="general"></a>
# ## Contenido
# ---
# # Módulo 3
# 1. [Agentes basados en el Conocimiento (KBA)](#uno)
#
#     * [Arquitectura de un KBA](#uno_a)
#     * [Lenguajes de representación de conocimiento](#uno_b)
#         * [Lógica](#uno_b_a)
#     * [Inferencia probabilista](#uno_c)
#     * [Enfoque bayesiano](#uno_d)
#     * [Redes Bayesianas](#uno_e)
#         * [Programación probabilística y PyMC3 - ejemplos](#uno_f)
#
# ---
# # Módulo 4
# 2. [Introducción al Aprendizaje Máquina](#dos)
#
#     * Aprendizaje computacional.
#     * Perceptrón.
#     * Minería de datos.
#     * Inducción.
#     * Arboles de decisión.
#     * Algoritmos de construcción de árboles de decisión.
#     * Modelos básicos de redes neuronales.
#     * Redes de retropropagación.

# %% [markdown]
# ---
# <a id = "uno"></a>
#
# # 1.- Agentes basados en el Conocimiento (KBA)
#
# [Regreso a contenido](#general)
#
# ---
#
# Al momento hemos platicado acerca de varios tipos de agentes. Bastante se ha platicado de aquellos basados en **objetivos**; mejor preparados que los agentes simples...
#
# Cuando "dotamos" de razonamientos a nuestros agentes, pueden llegar a obtener un mejor desempeño realizando tareas más complejas.
#
# * Un agente basado en el **Conocimiento** utiliza cierto razonamiento para decidir las acciones que le llevarán a su objetivo.
#
# <img src="https://media.tenor.com/images/f5c4c7cd66f0a698a55c9d09494e7928/tenor.gif" width="300" align="center">
#
# ---
#
# Necesitamos 2 cosas importantes: **Base de conocimiento** y **Máquina de inferencia**.
#
# De tal manera que en estas características se encuentre una representación explícita del conocimiento, una capacidad de razonamiento **independiente** y capacidad de explicar las conclusiones y el proceso de razonamiento...
#
# ---
#
# Se necesita conocimiento muy variado!
# * Sobre el mundo: estado actual, cómo inferir sus propiedades a partir de percepciones, cómo evalua...
# * Sobre el objetivo a conseguir
# * Sobre las acciones a realizar dependiendo las circunstancias
#
# ---
#
# Una Base de Conocimiento (KB) tiene hechos representados en forma de sentencias, por lo que las sentencias se escriben en el Lenguaje de Representación del Conocimiento (KRL).
#
# A partir de lo anterior, podemos decir que los mecanismos de inferencia determinan que hechos se deducen a partir del conocimiento y podemos describir un agente basado en conocimiento en tres niveles:
#
# * epistemológico o del conocimiento: descripción de lo que conoce el agente en un nivel abstracto
# * lógico: sentencias de la base de conocimiento
# * implementación: representaciones físicas de las sentencias de la KB
#
# Con el objetivo de añadir aprendizaje: **agente autónomo**

# %% [markdown]
# ---
# <a id = "uno_a"></a>
#
# ### 1.1. Arquitectura de un KBA
#
# [Regreso a contenido](#general)
#
# ---
#
#
# Por lo tanto, debe asegurar que la respuesta a cualquier consulta sea mediente una especie de inferencia, ya sea **deductiva** o **inductiva**.
#
# <img src="https://slideplayer.com/slide/15093412/91/images/7/Generic+KB-based+agent+pseudocode.jpg" width="600" align="center">
#
# ---
#
# Nuestro agente debe ser capas de:
# * Representar estados, acciones, etc...
# * Incorporar nuevas percepciones
# * Actualizar representaciones internas del mundo
# * Deducir propiedades escondidas del mundo
# * Deducir acciones apropiadas

# %% [markdown]
# ---
# <a id = "uno_b"></a>
#
# ### 1.2. Lenguajes de representación del conocimiento
#
# [Regreso a contenido](#general)
#
# ---
#
# Un buen lenguaje de representación del conocimiento deberá ser:
# * expresivo y conciso
# * independiente del contexto y no ambigüo
# * contar con un mecanismo de inferencia asociado
#
# Donde la sintaxis define las sentencias del lenguaje y la semántica define el **significado** de las sentencias, es decir, define la verdad de una sentencia en un mundo dado.
#
#
# ---
# <a id = "uno_b_a"></a>
# ### 1.2.1. Lógica
#
# [Regreso a contenido](#general)
#
# ---
#
# Lenguaje que permite expresar conocimiento y razonar a partir de ciertas expresiones para deducir otras...
#
# Características:
# * sintaxis y semántica bien definidas
# * reglas de inferencia
#
# #### Lógica Proposicional
# Permite expresar y razonar con declaraciones que son Verdaderas o Falsas
#
# Ejemplos:
#
# * La clase de IA es lo mejor que me ha pasado en la vida
# * La Lógica es fácil
#
# <img src="https://i.imgflip.com/4g9pfy.jpg" width="300" align="center">
#
# Por ejemplo:
#
# | Operation                | Book | Python Infix Input | Python Output | Python `Expr` Input
# |--------------------------|----------------------|-------------------------|---|---|
# | Negation                 | &not; P      | `~P`                       | `~P` | `Expr('~', P)`
# | And                      | P &and; Q       | `P & Q`                     | `P & Q` | `Expr('&', P, Q)`
# | Or                       | P &or; Q | `P`<tt> &#124; </tt>`Q`| `P`<tt> &#124; </tt>`Q` | `Expr('`&#124;`', P, Q)`
# | Inequality (Xor)         | P &ne; Q     | `P ^ Q`                | `P ^ Q`  | `Expr('^', P, Q)`
# | Implication                  | P &rarr; Q    | `P` <tt>&#124;</tt>`'==>'`<tt>&#124;</tt> `Q`   | `P ==> Q` | `Expr('==>', P, Q)`
# | Reverse Implication      | Q &larr; P     | `Q` <tt>&#124;</tt>`'<=='`<tt>&#124;</tt> `P`  |`Q <== P` | `Expr('<==', Q, P)`
# | Equivalence            | P &harr; Q   | `P` <tt>&#124;</tt>`'<=>'`<tt>&#124;</tt> `Q`   |`P <=> Q` | `Expr('<=>', P, Q)`

# %% [markdown]
# ---
# <a id = "uno_c"></a>
# ### &#9991; <u> 1.3. Inferencia probabilista</u>
#
# [Regreso a contenido](#general)
#
# ---

# %% [markdown]
# ### Ejemplo introductorio: Cajas con Frutas
# Supongamos que tenemos dos cajas, una caja roja que contiene 2 Manzanas y 6 Duraznos, y una caja azul que contiene 3 Manzanas y 1 Durazno.
#
# <img src="https://media2.giphy.com/media/3o6ZsSV7QcZDPlPJIc/source.gif" width=200/>
#
# Experimento(s):
# * <u>Elegimos una caja al azar</u> y <u>sacamos una fruta al azar</u>.
# * Habiendo observado qué fruta es, la volvemos a colocar en la caja de donde salió (muestreo con reemplazo).
# * Hacemos esto muchas veces; i.e. corremos el experimento varias veces (_trials_).
#
# Condiciones de partida (supuestos):
# * Supongamos que en este proceso tomamos la caja <b>roja 40%</b> de las veces y la caja <b>azúl 60%</b>.
# * Supongamos también que al devolver la fruta elegida al azar, cualquier otra fruta es igualmente probable de ser elegida la próxima vez (muestreo independiente).

# %% [markdown]
# ### Formalización del Experimento y sus Resultados:
#
# #### Variable aleatoria, evento, distribución de probabilidad, valor de probabilidad
# * **La identidad de la caja** es una **_Variable Aleatoria_** (VA) que llamaremos $C$. Esta VA tiene **dos valores posibles**: $r$ (cuando se elige la caja roja) y $a$ (cuando elegimos la caja azúl).
# * La identidad de la fruta es una VA ($F$), cuyos valores posibles son $m$ y $d$.
# * Llamaremos un **_Evento_** el **resultado** de "elegir una caja al azar".
# * De esta forma, tenemos dos eventos posibles respecto de la primera parte del experimento: $C=r$ o $C=a$.
# * Llamaremos $P(C)$ la **distribución de probablidad** de $C$ y $p(C=x)$ el valor de probabilidad de que $C=x$.
# * Del ejemplo tenemos: $p(C=r)=4/10$ y $p(C=a)=6/10$; las respectivas proporciones de cada evento. Por definición los valores de probabilidad se encuentran en el intervalo $[0,1]$.
# * Para simplificar la notación escribiremos: $p(r)=0.4$ o $p(a)=0.6$.
# * Nota la diferencia entre el valor que puede tomar la VA ($r$ o $a$) y el valor de probabilidad de cada valor posible de la variable ($p(r)$ o $p(a)$).
# * Si los eventos son mutuamente excluyentes e incluyen todos los resultados posibles (como es el caso), entonces la suma de sus probabilidades es $1$: $p(r)+p(a)=1$.
# * A partir de aquí, nos podemos hacer varias preguntas. Por ejemplo, ¿Cuál es la probabilidad de elegir una Manzana? o ¿Dado que elegimos un Durazno, qué probablidad hay de que haya provenido de la caja azúl?
# * Para responder este tipo de preguntas, necesitamos utilizar las **_reglas de inferencia_** de la Teoría de Probabilidad.

# %% [markdown]
#  ### Regla del Producto y Regla de la Suma

# %% [markdown]
# #### **Ilustración gráfica**.
#
# * Supongamos dos VA $X$ y $Y$. Supongamos además que $X$ tiene $i=1,\ldots,M$ valores posibles y $Y$ tiene $j=1,\ldots,L$ valores posibles, que denominaremos $x_i$ y $y_j$ respectivamente.
# * Supongamos que corremos el experimento $N$ veces (trials) y que en cada corrida muestreamos el valor de $X$ y de $Y$.
# * Sea $n_{ij}$ el **número de veces** en que $X=x_i$ y $Y=y_j$.
# * Sea $c_i$ el número de veces en que $X=x_i$ (independientemente de cuanto valga $Y$).
# * Sea $r_j$ el número de veces en que $Y=y_j$ (independientemente de cuanto valga $X$).
#
# <img src="https://pi.math.cornell.edu/~mec/Winter2009/RalucaRemus/Lecture1/Images/multiplication0.gif" width=300/>
# <em><center>Ilustración de dos VA $X$ y $Y$: $X$ puede tomar 5 valores posibles y $Y$ 3. </center></em>
#
# <u>Probabilidad Conjunta</u>
#
# Es la probabilidad de que $X=x_i$ y $Y=y_j$ de manera simultánea (conjuntamente). Se escribe: $p(X=x_i,Y=y_j)$ y está dada por la proporción de veces en que ocurre esta conjunción (celda $(i,j)$) respecto del total de observaciones.
#
# <center>$p(x_i,y_j)=\frac{n_{ij}}{N}$ &emsp;&emsp;&emsp;&emsp; (1)</center>
#
# <u>Probabilidad Marginal (Regla de la Suma)</u>
#
# Es la probabilidad de que $X=x_i$ de manera aislada (independientemente del valor de $Y$). Se escribe: $p(X=x_i)$ y está dada por la proporción del total de veces en que $X=x_i$ respecto del total de observaciones.
#
# <center>$p(x_i)=\frac{c_{i}}{N}$ &emsp;&emsp;&emsp;&emsp; (2)</center>
#
# &#9758; Puesto que el número de instancias $c_i$ es el valor total de instancias en la columna $i$, tenemos que $c_i=\sum n_{ij}$. Por lo tanto, de (1) y (2) tenemos:
# $$
# p(X=x_i)=\sum_{j=1}^{L} p(X=x_i,Y=y_j) \;\;\;\;\;\;(3)
# $$
#
# <u>Probabilidad Condicional</u>
#
# Si consideramos sólo las instancias en que $X=x_i$, la fracción de estas instancias en las que $Y=y_j$ se escribe: $p(Y=y_j|X=x_i)$ y se le llama probabilidad condicional de $Y=y_j$ dado que $X=x_i$. Es la fracción de puntos que están en la columna $c_i$ que caen en la celda $(i,j)$:
#
# <center>$p(y_j|x_i)=\frac{n_{ij}}{c_{i}}$ &emsp;&emsp;&emsp;&emsp; (4)</center>

# %% [markdown]
# #### **Regla del Producto:**
#
# &#9758; De (1), (2) y (4) tenemos la siguiente relación:
#
# $$
# p(X=x_i,Y=y_j) = \frac{n_{ij}}{N} = \frac{n_{ij}}{c_i}\cdot\frac{c_{i}}{N} = p(Y=y_j|X=x_i)p(X=x_i) \;\;\;\;\;\;(5)
# $$
#
# $$
# P(X,Y) = P(Y|X)P(X) \;\;\;\;\;\;(6)
# $$
#
# #### **Regla de la Suma:**
#
# $$
# p(X)=\sum_{Y} P(X,Y) \;\;\;\;\;\;(7)
# $$

# %% [markdown]
# &#9758; Estas expresiones se refieren a distribuciones de probabilidad **discreta**. Debes tomar en cuenta que se trata de Tablas, donde se van llenando los valores de probabilidad para cada valor de $x_i$ y $y_j$.
#
# Para nuestro ejemplo de Cajas ($X$) y Frutas ($Y$), las Tablas de distribución tendrían una aspecto similar a estos:
# <table width="80%">
#     <tr>
#         <td valign="top">
#             <table width="70%">
#               <tr>
#                 <th> $X$</th>
#                 <th><p style="text-align:center;"> $P(X)$</p></th>
#               </tr>
#               <tr>
#                 <td><p style="text-align:center;">$r$</p></td>
#                 <td><p style="text-align:center;">$p(r)$</p></td>
#               </tr>
#               <tr>
#                 <td><p style="text-align:center;">$a$</p></td>
#                 <td><p style="text-align:center;">$p(a)$</p></td>
#               </tr>
#             </table>
#         </td>
#         <td valign="top">
#             <table >
#               <tr>
#                 <th> $X, Y$</th>
#                 <th><p style="text-align:center;"> $P(X,Y)$</p></th>
#               </tr>
#               <tr>
#                 <td><p style="text-align:center;">$r,m$</p></td>
#                 <td><p style="text-align:center;">$p(r,m)$</p></td>
#               </tr>
#               <tr>
#                 <td><p style="text-align:center;">$r,d$</p></td>
#                 <td><p style="text-align:center;">$p(r,d)$</p></td>
#               </tr>
#               <tr>
#                 <td><p style="text-align:center;">$a,m$</p></td>
#                 <td><p style="text-align:center;">$p(a,m)$</p></td>
#               </tr>
#               <tr>
#                 <td><p style="text-align:center;">$a,d$</p></td>
#                 <td><p style="text-align:center;">$p(a,d)$</p></td>
#               </tr>
#             </table>
#         </td>
#         <td valign="top">
#             <table >
#               <tr>
#                 <td style="height:1px;"> &nbsp;</td>
#                 <td colspan="2"><p style="text-align:center;">$P$($Y$|$X$)</p></td>
#               </tr>
#               <tr>
#                 <td>$X$</td>
#                 <td><p style="text-align:center;">$m$</p></td>
#                 <td><p style="text-align:center;">$d$</p></td>
#               </tr>
#               <tr>
#                 <td><p style="text-align:center;">$r$</p></td>
#                 <td><p style="text-align:center;">$p(m|r)$</p></td>
#                 <td><p style="text-align:center;">$p(d|r)$</p></td>
#               </tr>
#               <tr>
#                 <td><p style="text-align:center;">$a$</p></td>
#                 <td><p style="text-align:center;">$p(m|a)$</p></td>
#                 <td><p style="text-align:center;">$p(d|a)$</p></td>
#               </tr>
#             </table>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### Teorema de Bayes

# %% [markdown]
# De la regla del producto podemos observar que:
#
# $$
# P(X,Y) = P(Y|X)P(X) = P(X|Y)P(Y) \;\;\;\;\;\;(8)
# $$
#
# Despejando para $P(Y|X)$ tenemos el **Teorema de Bayes**:
#
# $$
# P(Y|X) = \frac{P(X|Y)P(Y)}{P(X)} \;\;\;\;\;\;(9)
# $$

# %% [markdown]
# Aplicando las ecuaciones (6) a (9) responde a las siguientes preguntas para nuestro ejemplo de Manzanas y Duraznos:
#
# <ol>
#     <li>¿Cuál es la probabilidad de elegir una Manzana?</li>
#     <li>¿Dado que elegimos un Durazno, qué probablidad hay de que haya provenido de la caja azúl?</li>
# </ol>

# %% [markdown]
# Representemos $P(X)$, la distribución de X (el color de la caja)

# %%
import numpy as np
import pandas as pd

#PX={'r':4/10, 'a':6/10}. los datos:
data={'p':[4/10,6/10]}

#construimos el DF
PX=pd.DataFrame(data,index=['r','a'])

#Cambiamos el titulo del indice
PX.index.names = ['X']
PX.columns.names = ['P(X)']

print('p(X=r) = {0}; p(X=a) = {1}'.format(PX['p']['r'],PX['p']['a']))
PX

# %% [markdown]
# &#9998; **Calcula $P(Y|X)$. ¿Qué representa esta distribución para nuestro ejemplo?**

# %%
# TIP: de los datos de partida, encuentra:
# pm_r,pm_a
# pd_r,pd_a

#luego construye el diccionario 'data'
data=[{'m': 0.25,'d': 0.75},
      {'m':0.75,'d':0.25}] 

#construimos el DF
PY_X=pd.DataFrame(data,index=["r", "a"])
PY_X.index.names = ['X']
PY_X.columns.names = ['P(Y|X)']
PY_X

# %% [markdown]
# &#9998; **¿Cuál es la probabilidad de elegir una Manzana?**
#
# * ¿Cómo se representa la probabilidad de esta pregunta?
# * Calcúlala
# * Proporciona la distribución completa $P(Y)$

# %%
#La probabilidad de elegir una manzana se escribe: P(Y=m)

# P(X,Y)=P(X)P(Y|X) Regla del producto
# Para X=r y Y=m -> p(r,m)=p(r)*p(m|r)
prm=PX['p']['r']*PY_X['m']['r']
# Para X=a y Y=m -> p(a,m)=p(a)*p(m|a)
pam=PX['p']['a']*PY_X['m']['a']

# P(Y=m)=Sum_X{P(X,Y=m)} Regla de la suma
p_m=prm+pam #Regla de la suma

# Para X=r y Y=d -> p(r,d)=p(r)*p(d|r)
prd=PX['p']['r']*PY_X['d']['r']
# Para X=a y Y=d -> p(a,d)=p(a)*p(d|a)
pad=PX['p']['a']*PY_X['d']['a']
p_d=prd+pad #Regla de la suma

print('La suma de P(Y=m)+P(Y=d) = ',p_m+p_d)

data={'p':[p_m,p_d]}

#construimos el DF
PY=pd.DataFrame(data,index=['m','d'])

#Cambiamos el titulo del indice
PY.index.names = ['Y']
PY.columns.names = ['P(Y)']

print('p(Y=m) = {0}; p(Y=d) = {1}'.format(PY['p']['m'],PY['p']['d']))
PY

# %% [markdown]
# &#9998; **¿Dado que elegimos un Durazno, qué probablidad hay de que haya provenido de la caja azúl?**
#
# * ¿Cómo se representa la probabilidad de esta pregunta?
# * Calcúlala
# * Proporciona la distribución completa

# %%
# P(X=a|Y=d) => usando la Regla de Bayes P(X|Y)=P(X,Y)/P(Y) 
# P(X=a|Y=d) = P(X=a)P(Y=d|X=a)/P(Y=d) 
pa_d=PX['p']['a']*PY_X['d']['a']/PY['p']['d']

# P(X=r|Y=d) = P(X=r)P(Y=d|X=r)/P(Y=d) 
pr_d=PX['p']['r']*PY_X['d']['r']/PY['p']['d']

# P(X=a|Y=m) = P(X=a)P(Y=m|X=a)/P(Y=m) 
pa_m=PX['p']['a']*PY_X['m']['a']/PY['p']['m']

# P(X=r|Y=m) = P(X=r)P(Y=m|X=r)/P(Y=m) 
pr_m=PX['p']['r']*PY_X['m']['r']/PY['p']['m']


data=[{'r': pr_m,'a': pa_m},
      {'r':pr_d,'a':pa_d}] 

#construimos el DF
PX_Y=pd.DataFrame(data,index=["m", "d"])
PX_Y.index.names = ['Y']
PX_Y.columns.names = ['P(X|Y)']
PX_Y

# %% [markdown]
# ---
# <a id = "uno_d"></a>
#
# ## 1.4. <u>Enfoque Bayesiano: inferencia con incertidumbre</u>
#
# [Regreso a contenido](#general)
#
# ---

# %% [markdown]
# * El ejemplo la caja con frutas, es un clásico ejemplo de cómo se utilizan las reglas de inferencia probabilista, bajo un **enfoque frecuentista**.
# * En algunas ocasiones es prácticamente imposible realizar un conteo de ciertos fenómenos o situaciones reales. Pensemos en la situación actual de la pandemia covid19. ¿Habrá desaparecido el riesgo de contagio en México en el 2021? Esta es una pregunta sobre la que no tenemos forma de repetir experimentos y calcular una probabilidad en la misma forma que en el ejemplo de las frutas.
# * Aún así, es posible tener una estimación de la velocidad de contagio y de la disminución del número de personas infectadas hasta ahora. Con ello, podríamos hacernos una idea (**una creencia** o **hipótesis**) sobre la respuesta a la pregunta.
# * Esta  **creencia a priori**, sin embargo, tendría que **modificarse** conforme vayamos teniendo **nueva evidencia** sobre el comportamiento de los contagios.
# * La evaluación de estos aspectos nos llevaría a **tomar decisiones**, cuyos efectos deberíamos ser capaces de observar para validar nuestras hipótesis.
# * Ante estas circunstancias, es deseable tener una forma de **medir la incertidumbre** alrededor de nuestras hipótesis, y hacer revisiones de esta incertidumbre a la luz de nueva información.
# * Esto se logra gracias a la elegante interpretación de la probabilidad bayesiana.

# %% [markdown]
# ### Re-interpretación del Teorema de Bayes
#
# ---
# ![imagen.png](attachment:imagen.png)

# %% [markdown]
# &#128214; <u>Orígenes del bayesianismo</u>:
# <br>
# <ul>
#     <li> Biografía de <a href="https://es.wikipedia.org/wiki/Thomas_Bayes"> Thomas Bayes</a> en Wikipedia</li>
#     <li> <a href="https://en.wikipedia.org/wiki/Cox%27s_theorem"> Cox's Theorem</a> en Wikipedia</li>
#     <li> Cox, R. T. (1946). "Probability, Frequency and Reasonable Expectation". American Journal of Physics. 14: 1–10. doi:<a href="https://aapt.scitation.org/doi/10.1119/1.1990764">10.1119/1.1990764</a>. </li>
#     <li>Cox, R. T. (1961). The Algebra of Probable Inference. Baltimore, MD: Johns Hopkins University Press. </li>
#     <li><a href="https://en.wikipedia.org/wiki/Edwin_Thompson_Jaynes">Jaynes, E.T.</a> (2003). Probability Theory - The Logic of Science.  Cambridge University Press. doi: <a href="https://www.cambridge.org/core/books/probability-theory/9CA08E224FF30123304E6D8935CF1A99">10.1017/CBO9780511790423</a></li>
# </ul>

# %% [markdown]
# &#128214; <u>Algunas herramientas y productos sobre inferencia probabilística y bayesiana</u>
# * [Repositorio de Kevin Murphy](https://www.cs.ubc.ca/~murphyk/Software/bnsoft.html), actualizado hasta el 16 de Junio de 2014.
# * [PyMC3](https://docs.pymc.io/) software libre de programación probabilística en Python.
# * [Stan](https://mc-stan.org/) es una plataforma open-source para el modelado estadístico y el cálculo estadístico de alto rendimiento. Cuenta con interfaces para R, Python, shell, MATLAB, Julia y Stata, y corre en plataformas Linux, Mac y Windows.
# * [Netica](https://www.norsys.com/) es una herramienta comercial para modelar redes bayesianas.
# * [Infer.NET](https://www.microsoft.com/en-us/research/project/infernet/) es una herramienta en desarrollo de Microsoft Research que combina modelos gráficos con programación probabilista.
# * [Hugin expert](https://www.hugin.com/) es otra herramienta comercial para desarrollar redes bayesianas. Una de las primeras disponibles en el mercado hace más de 20 años.
# * [BUGS (Bayesian inference Using Gibbs Sampling)](http://www.openbugs.net/w/FrontPage): un proyecto muy activo descrito en _The BUGS book: a practical introduction to Bayesian analysis_ (Lunn et al. 2012). Una introducción al libro puede encontrarse en este [Review](https://pdfs.semanticscholar.org/542e/05cbeeb2674827c5b99e0fb87d37bc7eb3c7.pdf?_ga=2.157056635.171412260.1590004611-1055786045.1581021538).
# * [ProBT](https://team.inria.fr/e-motion/en/software/) es un motor de inferencia y una herramienta de cómputo desarrollada por [ProBayes](https://www.probayes.com/notre-histoire/) para diseñar e implementar el paradigma de la [_Programación Bayesiana_](https://en.wikipedia.org/wiki/Bayesian_programming), que esencialmente tiene sus fundamentos en el enfoque de [Edwin T. Jaynes](https://en.wikipedia.org/wiki/Edwin_Thompson_Jaynes), quien veía a la Teoría de la Probabilidad como una extensión de la Lógica.
# * [The t-walk software](https://www.cimat.mx/~jac/twalk/). J. Andres Christen (CIMAT, Mexico) y Colin Fox (U. of Otago, New Zealand), es un algoritmo de muestreo de propósito general para distribuciones continuas "para tomar muestras de muchas funciones objetivo (especialmente adecuado para distribuciones posteriores que utilizan modelos no estándares que dificultarían el uso de algoritmos y software comunes); es un MCMC que no requiere ajuste.

# %% [markdown]
# ---
# ---
#
# <a id="uno_e"></a>
#
# ### 1.5. Redes Bayesianas
#
# [Regreso a contenido](#general)

# %% [markdown]
# Un tipo de sistema experto ampliamente usado hoy en día es el basado en una red bayesiana. En esencia, consiste en un gráfico que representa un conjunto de variables conocidas y las relaciones de dependencia entre ellas a fin de inferir, es decir, estimar la probabilidad, de las variables no conocidas. Dadas sus características, este modelo resulta idóneo para la clasificación, la predicción o el diagnóstico.
#
# <img src="https://jpordonez.files.wordpress.com/2008/08/12.jpg" weidth="300" align="center"/>
#
# ---
#
# Imaginemos que disponemos de dos variables para que pueden determinar que la hierba de un jardín esté húmeda: que el rociador esté activado o que esté lloviendo (suponiendo que si llueve, el rociador se apaga).
#
# Una vez disponemos de estas variables, podemos crear un modelo bayesiano en el que las tres variables tienen dos posibles valores (T verdadero, F falso). Las tres variables son: G = Hierba húmeda, S = Rociador activado, y R = Lluvia.
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/9/97/Red_Bayesiana_Simple.png/400px-Red_Bayesiana_Simple.png" weidth="600" align="center"/>

# %% [markdown]
# Las redes bayesianas han dado forma a problemas complejos que proporcionan información y recursos limitados.
#
# Se está implementando en las tecnologías más avanzadas de la era, como la inteligencia artificial y el aprendizaje automático. Tener un sistema de este tipo es una necesidad en el mundo centrado en la tecnología de hoy....
#
# ---
#
# <h3><center>¿Qué es una red bayesiana?</center></h3>
#
# ---
#
#
#
# Una red bayesiana se incluye en la categoría de técnica de modelado gráfico probabilístico (PGM) que se utiliza para calcular incertidumbres mediante el concepto de probabilidad. Popularmente conocidas como redes de creencias, las redes bayesianas se utilizan para modelar incertidumbres mediante gráficos acíclicos dirigidos (DAG).
#
# Esto nos lleva a la pregunta:
#
# ---
#
# <h3><center>¿Qué es un gráfico acíclico dirigido?</center></h3>
#
# ---
#
# Un gráfico acíclico dirigido se utiliza para representar una red bayesiana y, como cualquier otro gráfico estadístico, un DAG (Directed Acyclic Graph) contiene un conjunto de nodos y enlaces, donde los enlaces denotan la relación entre los nodos.
#
# <img src="https://d1jnx9ba8s6j9r.cloudfront.net/blog/wp-content/uploads/2019/07/Directed-Acyclic-Graphs-Bayesian-Networks-Edureka-428x300.png" align="center" weidth="300"/>

# %% [markdown]
# ---
#
# <h3><center>Ejemplo de redes bayesiana</center></h3>
#
# ---
#
# Supongamos que estamos creando una Red Bayesiana que modelará las calificaciones (m) de un estudiante en su examen. Las marcas dependerán de:
#
# * Nivel de examen (e): esta es una variable discreta que puede tomar dos valores (difícil, fácil)
#
# * CI del alumno (i): una variable discreta que puede tomar dos valores (alto, bajo)
#
# Las notas predecirán si el estudiante será admitido o no (a) en una universidad. El coeficiente intelectual también predecirá la puntuación de aptitud del estudiante.
#
# Con esta información, podemos construir una Red Bayesiana que modelará el desempeño de un estudiante en un examen. La Red Bayesiana se puede representar como un DAG donde cada nodo denota una variable que predice el desempeño del estudiante.
#
# <img src="https://d1jnx9ba8s6j9r.cloudfront.net/blog/wp-content/uploads/2019/07/Bayesian-Networks-Example-Bayesian-Networks-Edureka.png" align="center" weidth="300"/>
#
# ---
#
# Arriba se representa esta distribución a través de un DAG y una tabla de probabilidad condicional. Ahora podemos calcular la distribución de probabilidad conjunta de estas 5 variables, es decir, el producto de probabilidades condicionales:
#
# <img src="https://d1jnx9ba8s6j9r.cloudfront.net/blog/wp-content/uploads/2019/07/Joint-Probability-Distribution-Bayesian-Networks-Edureka-528x49.png" align="center" weidth="300"/>
#
# donde,
#
#    * $p (a | m)$ representa la probabilidad condicional de que un estudiante obtenga una admisión basada en sus calificaciones.
#
#    * $p (m | i, e)$ representa la probabilidad condicional de las calificaciones del estudiante, dado su nivel de CI y nivel de examen.
#
#    * $p (i)$ denota la probabilidad de su nivel de CI (alto o bajo)
#
#    * $p (e)$ denota la probabilidad del nivel de examen (difícil o fácil)
#
#    * $p (s | i)$ denota la probabilidad condicional de sus puntuaciones de aptitud, dado su nivel de CI

# %% [markdown]
# ---
# El DAG muestra claramente cómo cada variable (nodo) depende de su nodo principal, es decir, las calificaciones del estudiante dependen del nivel de examen (nodo principal) y el nivel de IQ (nodo principal). Del mismo modo, la puntuación de aptitud depende del nivel de CI (nodo padre) y, finalmente, su admisión en una universidad depende de sus notas (nodo padre). Esta relación está representada por los bordes del DAG.
#
# Podemos ver un patrón aquí. La probabilidad de una variable aleatoria depende de sus padres. Por tanto, podemos formular Redes Bayesianas como:
#
# <img src="https://d1jnx9ba8s6j9r.cloudfront.net/blog/wp-content/uploads/2019/07/Bayesian-Networks-Formula-Bayesian-Networks-Edureka-1-528x36.png" align="center" weidth="300"/>
#
# ---
#
# Donde, $X_i$ denota una variable aleatoria, cuya probabilidad depende de la probabilidad de los nodos padres, $𝑃𝑎𝑟𝑒𝑛𝑡𝑠 (𝑋_𝑖)$.
#
# Simple, ¿no es así? Las redes bayesianas son una de las técnicas más simples pero efectivas que se aplican en el modelado predictivo, el análisis descriptivo, etc.

# %% [markdown]
# ---
# ---
#
# <a id="uno_f"></a>
#
# ### 1.5.1 Programación probabilística y PyMC3 - ejemplos
#
# [Regreso a contenido](#general)
#
# <h3><center> Programación probabilística y PyMC3</center></h3>
#
# A pesar de que las redes bayesianas y demás modelos de inferencia bayesiana son conceptualmente simples; a menudo los cálculos de sus probabilidades conducen a expresiones que no se pueden resolver en forma analítica. Durante muchos años, este fue un gran problema y fue probablemente una de las principales razones que obstaculizaron la adopción de los métodos bayesianos. La llegada de las computadoras y el desarrollo de métodos numéricos que se pueden aplicar para calcular la distribución a posteriori de casi cualquier modelo, junto con el avance en las técnicas de muestreo de los métodos de Monte-Carlo; han transformado completamente la práctica del análisis de datos Bayesiano.
#
# ---
#
# La posibilidad de automatizar la inferencia probabilística ha conducido al desarrollo de la Programación probabilística, la cuál utiliza las ventajas de los lenguajes de programación modernos y nos permite realizar una clara separación entre la creación del modelo y el proceso de inferencia. En Programación probabilística, especificamos un modelo probabilístico completo escribiendo unos cuantos líneas de código y luego la inferencia se realiza en forma automática.

# %% [markdown]
# <h3><center> Ejemplos - El problema de la moneda</center></h3>
#
# Los problemas de monedas son clásicos cuando hablamos de probabilidad y estadística, nos permiten ejemplificar conceptos abstractos de forma simple. Asimismo, pueden ser muchas veces conceptualmente similares a situaciones reales, de hecho cualquier problema en donde obtengamos resultados binarios, 0/1, enfermo/sano, spam/no-spam, puede ser pensado como si estuviéramos hablando de monedas. En este caso, la idea es utilizar un modelo bayesiano para inferir si la moneda se encuentra sesgada o no.
#
# Para este ejemplo, vamos a utilizar una distribución binomial como likelihood y una distribución beta como a priori. Veamos como lo podemos modelar con PyMC3.
#
# # **Para facilitar las cosas, favor de ejecutar este código en colab**...

# %%
# importando modulos necesarios
import matplotlib.pyplot as plt 
import numpy as np 
import pandas as pd
import scipy.stats as stats
import seaborn as sns
import pymc3 as pm
import theano.tensor as tt
from sklearn import datasets
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split

np.random.seed(1984) #replicar random

# %matplotlib inline

# %%
# El problema de la moneda
# de 100 lanzamientos 80 caras
n = 100
caras = 80

# %%
# Creación del modelo
niter = 2000
with pm.Model() as modelo_moneda:
    # a priori
    p = pm.Beta('p', alpha=2, beta=2)
    # likelihood
    y = pm.Binomial('y', n=n, p=p, observed=caras)

# %%
# Realizando el muestreo para la inferencia
with modelo_moneda:
    trace = pm.sample(niter, cores=4)

# %%
# Analizando los resultados
pm.traceplot(trace, varnames=['p'], lines={'p':.8})
pass

# %%
# Información resumen. 
#Vemos que hay un 95% de probabilidades de que el valor de sesgo este entre
# .706 y .864
pm.summary(trace)

# %% [markdown]
# Como vemos el modelo nos indica que la moneda parece tener un claro sesgo hacia cara.

# %% [markdown]
# <h3><center>Ejemplos - El problema de la hierba mojada</center></h3>
#
# Supongamos que hay dos eventos los cuales pueden causar que la hierba esté húmeda: que el rociador esté activado o que esté lloviendo. También supongamos que la lluvia tiene un efecto directo sobre el uso del rociador (usualmente cuando llueve el rociador se encuentra apagado). Entonces la situación puede ser modelada con la siguiente red bayesiana.

# %%
# Problema de la hierba mojada
# https://es.wikipedia.org/wiki/Red_bayesiana#Ejemplo
niter = 10000  # 10000
tune = 5000  # 5000

modelo = pm.Model()

with modelo:
    tv = [1]
    lluvia = pm.Bernoulli('lluvia', 0.2, shape=1, testval=tv)
    rociador_p = pm.Deterministic('rociador_p', 
                                  pm.math.switch(lluvia, 0.01, 0.40))
    rociador = pm.Bernoulli('rociador', rociador_p, shape=1, testval=tv)
    hierba_mojada_p = pm.Deterministic('hierba_mojada_p', 
                pm.math.switch(lluvia, pm.math.switch(rociador, 0.99, 0.80),
                               pm.math.switch(rociador, 0.90, 0.0)))
    hierba_mojada = pm.Bernoulli('hierba_mojada', hierba_mojada_p,
                             observed=np.array([1]), shape=1)

    trace = pm.sample(20000, 
                      step=[pm.BinaryGibbsMetropolis([lluvia, rociador])], 
                      tune=tune, random_seed=124)

# pm.traceplot(trace)

dictionary = {
              'lluvia': [1 if ii[0] else 0 for ii in trace['lluvia'].tolist() ],
              'rociador': [1 if ii[0] else 0 for ii in trace['rociador'].tolist() ],
              'rociador_p': [ii[0] for ii in trace['rociador_p'].tolist()],
              'hierba_mojada_p': [ii[0] for ii in trace['hierba_mojada_p'].tolist()],
              }
df = pd.DataFrame(dictionary)

p_lluvia = df[(df['lluvia'] == 1)].shape[0] / df.shape[0]
print("\nProbabilidad de que la hierba este mojada por la lluvia: {0}"
      .format(p_lluvia))

p_rociador = df[(df['rociador'] == 1)].shape[0] / df.shape[0]
print("Probabilidad de que la hierba este mojada por el rociador: {0}"
      .format(p_rociador))

# %% [markdown]
# De acuerdo a los resultados de la red bayesiana, si vemos que la hierba esta mojada, la probabilidad de que este lloviendo es alrededor del 38%.

# %% [markdown]
# <h3><center>Clasificador Bayes ingenuo (Naïve Bayes)</center></h3>
#
# Uno de los clasificadores más utilizados en Machine Learning por su simplicidad y rapidez, es el Clasificador Bayes ingenuo. El cual es una técnica de clasificación supervisada basada en el teorema de Bayes que asume que existe una independencia entre los atributos.
#
# ---
#
# En términos simples, un Clasificador Bayes ingenuo asume que la presencia de una característica particular en una clase no está relacionada con la presencia de cualquier otra característica.
#
#
# Por ejemplo, una fruta puede considerarse como una manzana si es roja, redonda y de aproximadamente 9 cm de diámetro. Incluso si estas características dependen unas de otras o de la existencia de otras características, todas estas propiedades contribuyen independientemente a la probabilidad de que esta fruta sea una manzana.
#
#
# Se lo llama ingenuo ya que asumir independencia absoluta entre todos los atributos, no es algo que se suela dar en la realidad. El modelo Bayes ingenuo es fácil de construir y particularmente útil para conjuntos de datos muy grandes. A pesar de su simplicidad y de su irealista postulado de independencia, este clasificador se ha mostrado muy efectivo y se suele utilizar como el estándar para evaluar el rendimiento de otros modelos de Machine Learning.

# %% [markdown]
# En este sencillo ejemplo (ver notebooke de ejercicios...), podemos ver como el Clasificador Bayes ingenuo ha clasificado correctamente la mayoría de los casos del dataset iris, obteniendo un efectividad del 93 %.

# %% [markdown]
# <h2><center>Inferencia Bayesiana estimada usando PyMC3</center></h2>
#
# ---
#
# Hasta este momento de la vida, hemos platicado acerca de los métodos bayesianos y su capacidad para generar estimaciones probabilísticas.
#
# Esto nos da la capacidad de generar modelos derivados basándose en expectativas a priori del comportamiento de los parámetros del modelo. Y nos lleva a que en lugar de obtener una solución de un solo punto, obtenemos una distribución de soluciones, cada una con una probabilidad asignada.
#
# <img src="https://www.researchgate.net/profile/Hideyoshi_Yanagisawa2/publication/330577376/figure/fig1/AS:718458304086017@1548305216392/Example-of-Bayesian-inference-with-a-prior-distribution-a-posterior-distribution-and.png"/>
#
# Las expectativas a priori del comportamiento de los datos se formulan en un conjunto de previos... distribuciones de probabilidad sobre los parámetros del modelo.

# %% [markdown]
# ---
#
# Hay innumerables razones por las que deberíamos aprender estadísticas bayesianas, en particular, la estadística bayesiana está emergiendo como un marco poderoso para expresar y comprender las redes neuronales profundas (CNN) de próxima generación.
#
# ---
#
# *Las cosas que tenemos que aprender antes de poder hacerlas, las aprendemos haciéndolas* (Práctica!).
#
# Y nada en la vida es tan difícil que no podamos hacerlo más fácil por la forma en cómo lo tomamos.
#
# <img src="https://media.tenor.com/images/b8718c934090ad1a36acd7ef9d0b846c/tenor.gif"/>
#
# ---

# %% [markdown]
# Antes de memorizar las infinitas terminologías, haremos algunos códigos y visualizaremos los resultados, acompañado de las terminologías y teorías para explicar los modelos en el camino.
#
# ---
#
# Los modelos bayesianos también se conocen como modelos probabilísticos porque se construyen utilizando probabilidades. Y usa probabilidades como herramienta para cuantificar la incertidumbre.
#
# Por lo tanto, las respuestas que obtenemos son distribuciones, no estimaciones puntuales.

# %% [markdown]
# ### Resumen de los pasos del enfoque Bayesiano
#
# * Paso 1: Establecer una creencia sobre los datos, incluidas las funciones Previas y Probabilidad.
#
# * Paso 2: usar los datos y la probabilidad de acuerdo con nuestra creencia de los datos para actualizar nuestro modelo... verifica que el modelo esté de acuerdo con los datos originales.
#
# * Paso 3: actualizar nuestra perspectiva de los datos según nuestro modelo.

# %% [markdown]
# ---
# ---
#
# ---
# <a id = "dos"></a>
#
# # 2.- Introducción al Aprendizaje de Máquina y sus Aplicaciones
#
# [Regreso a contenido](#general)
#
# ---

# %% [markdown]
# El Aprendizaje de Máquina (ML) está formando su propio nombre, con un reconocimiento en crecimiento que muestra que AM puede jugar un papel importante dentro de una gran gama de aplicaciones cruciales, como lo son:
# * minería de datos,
# * procesador de idioma natural,
# * reconocimiento de imagen y
# * sistemas de expertos.
#
# ML provee posibles soluciones en todos estos dominios y más. Además está creada para ser un pilar de nuestra civilización futura.
#
# <img src="https://uploads.toptal.io/blog/image/443/toptal-blog-image-1407508081138.png" weidth="200"/>

# %% [markdown]
# ---
#
# <h3><center>¿Qué Es El Aprendizaje De Máquina?</center></h3>
#
# ---
#
#
# ¿Entonces, qué es exactamente “Aprendizaje de Máquina”? Es de hecho muchas cosas. El campo es muy vasto y se está expandiendo rápidamente y continuamente está siendo particionado y sub-particionado sin descanso, en sub-especialidades y tipos de aprendizaje de máquina.
#
# ---
#
# Sin embargo, hay un denominador común básico y el tema dominador se resume mejor con esta declaración frecuentemente citada, hecha por Arthur Samuel en 1959: *ML es campo de estudio que da a las computadoras la habilidad de aprender sin ser programadas explícitamente.*
#
# ---
#
# Y más recientemente, en 1997, Tom Mitchell dio una definición “bien planteada” que ha demostrado ser más útil para los tipos de ingeniería: *Se dice que un programa de computadora aprende de experiencia E, con respecto a alguna tarea T y alguna medida de desempeño P, mejora con experiencia E.*

# %% [markdown]
# ---
#
# <h3><center>Resuelve problemas que no pueden ser resueltos a través de medios numéricos únicamente</center></h3>
#
# ---
#
# Entre los diferentes tipos de tarea AM, se traza una distinción crucial entre aprendizaje supervisado y no supervisado:
#
# * Aprendizaje de máquina supervisado: El programa está “entrenado” en un set pre-definido de “ejemplos de entrenamiento”, lo cual después facilitó su habilidad de alcanzar una conclusión acertada cuando se le pasa nueva data.
# * Aprendizaje de Máquina no supervisado: Al programa se le da una cantidad de data y debe encontrar patrones y relaciones dentro de éste.

# %% [markdown]
# # ¿Cómo se inicia el aprendizaje automático?
#
# La mejor manera de aprender el aprendizaje automático es diseñando y completando pequeños proyectos.
#
# ---
#
# ## Python puede ser intimidante al inicio... la verdad
#
# Cuando aplicamos el aprendizaje automático a nuestros propios conjuntos de datos, casi siempre debemos seguir los siguientes pasos:
#
#     Definir problema.
#     Preparar datos.
#     Evaluar algoritmos.
#     Mejorar los resultados.
#     Presentar resultados.

# %% [markdown]
# ### Hola mundo del aprendizaje automático
#
# El mejor proyecto para comenzar con una nueva herramienta es la clasificación de flores de iris (iris_dataset). Este es un buen proyecto porque se comprende muy bien los siguientes aspectos:
# * Los atributos son numéricos, por lo que debe averiguar cómo cargar y manejar los datos.
# * Es un problema de clasificación, lo que le permite practicar con quizás un tipo de algoritmo de aprendizaje supervisado más fácil.
# * Es un problema de clasificación de clases múltiples (multinominales) que puede requerir un manejo especializado.
# * Solo tiene 4 atributos y 150 filas, lo que significa que es pequeño y cabe fácilmente en la memoria.
# * Todos los atributos numéricos están en las mismas unidades y en la misma escala, por lo que no requieren ninguna escala especial o transformaciones para comenzar.

# %% [markdown]
# ## Cargar los datos
#
# Vamos a utilizar el conjunto de datos de flores de iris. Este conjunto de datos es famoso porque casi todo el mundo lo utiliza como el "hola mundo" en el aprendizaje automático y las estadísticas.
#
# El conjunto de datos contiene 150 observaciones de flores de iris. Hay cuatro columnas de medidas de las flores en centímetros. La quinta columna es la especie de flor observada. Todas las flores observadas pertenecen a una de las tres especies.

# %%
import pandas as pd

# %%
#ya sea cargar los datos de una url o de un archivo...
url = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/iris.csv"
names = ['sepal-length', 'sepal-width', 'petal-length', 'petal-width', 'class']
dataset = pd.read_csv(url, names=names)

# %%
#forma del dataset
print(dataset.shape)
# Out:
# (150, 5)

# %%
print(dataset.head(20))
# Out:
#     sepal-length  sepal-width  petal-length  petal-width        class
# 0            5.1          3.5           1.4          0.2  Iris-setosa
# 1            4.9          3.0           1.4          0.2  Iris-setosa
# 2            4.7          3.2           1.3          0.2  Iris-setosa
# 3            4.6          3.1           1.5          0.2  Iris-setosa
# 4            5.0          3.6           1.4          0.2  Iris-setosa
# 5            5.4          3.9           1.7          0.4  Iris-setosa
# 6            4.6          3.4           1.4          0.3  Iris-setosa
# 7            5.0          3.4           1.5          0.2  Iris-setosa
# 8            4.4          2.9           1.4          0.2  Iris-setosa
# 9            4.9          3.1           1.5          0.1  Iris-setosa
# 10           5.4          3.7           1.5          0.2  Iris-setosa
# 11           4.8          3.4           1.6          0.2  Iris-setosa
# ...

# %%
print(dataset.tail(20))
# Out:
#      sepal-length  sepal-width  petal-length  petal-width           class
# 130           7.4          2.8           6.1          1.9  Iris-virginica
# 131           7.9          3.8           6.4          2.0  Iris-virginica
# 132           6.4          2.8           5.6          2.2  Iris-virginica
# 133           6.3          2.8           5.1          1.5  Iris-virginica
# 134           6.1          2.6           5.6          1.4  Iris-virginica
# 135           7.7          3.0           6.1          2.3  Iris-virginica
# 136           6.3          3.4           5.6          2.4  Iris-virginica
# 137           6.4          3.1           5.5          1.8  Iris-virginica
# 138           6.0          3.0           4.8          1.8  Iris-virginica
# 139           6.9          3.1           5.4          2.1  Iris-virginica
# 140           6.7          3.1           5.6          2.4  Iris-virginica
# 141           6.9          3.1           5.1          2.3  Iris-virginica
# ...

# %%
#Resumen estadístico
print(dataset.describe())
# Out:
#        sepal-length  sepal-width  petal-length  petal-width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
#Distribución de clases
print(dataset.groupby('class').size())
# Out:
# class
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# dtype: int64

# %%
# summarize the data
from pandas import read_csv
# Load dataset
url = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/iris.csv"
names = ['sepal-length', 'sepal-width', 'petal-length', 'petal-width', 'class']
dataset = read_csv(url, names=names)
# shape
print(dataset.shape)
# head
print(dataset.head(20))
# descriptions
print(dataset.describe())
# class distribution
print(dataset.groupby('class').size())
# Out:
# (150, 5)
#     sepal-length  sepal-width  petal-length  petal-width        class
# 0            5.1          3.5           1.4          0.2  Iris-setosa
# 1            4.9          3.0           1.4          0.2  Iris-setosa
# 2            4.7          3.2           1.3          0.2  Iris-setosa
# 3            4.6          3.1           1.5          0.2  Iris-setosa
# 4            5.0          3.6           1.4          0.2  Iris-setosa
# 5            5.4          3.9           1.7          0.4  Iris-setosa
# 6            4.6          3.4           1.4          0.3  Iris-setosa
# 7            5.0          3.4           1.5          0.2  Iris-setosa
# 8            4.4          2.9           1.4          0.2  Iris-setosa
# 9            4.9          3.1           1.5          0.1  Iris-setosa
# 10           5.4          3.7           1.5          0.2  Iris-setosa
# 11           4.8          3.4           1.6          0.2  Iris-setosa
# ...

# %% [markdown]
# ## Visualización de datos
#
# ---
#
# ### Gráficos univariados
#
# Comenzamos con algunas gráficas univariadas, es decir, gráficas de cada variable individual.
#
# Dado que las variables de entrada son numéricas, podemos crear diagramas de caja y bigotes de cada una.

# %%
import matplotlib.pyplot as pt
# box and whisker plots
dataset.plot(kind='box', subplots=True, layout=(2,2), sharex=False, sharey=False)
pt.show()

# %%
# histograms
dataset.hist()
pt.show()

# %%
# scatter plot matrix
from pandas.plotting import scatter_matrix
scatter_matrix(dataset)
pt.show()

# %%
# Load dataset
url = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/iris.csv"
names = ['sepal-length', 'sepal-width', 'petal-length', 'petal-width', 'class']
dataset = read_csv(url, names=names)
# box and whisker plots
dataset.plot(kind='box', subplots=True, layout=(2,2), sharex=False, sharey=False)
pt.show()
# histograms
dataset.hist()
pt.show()
# scatter plot matrix
scatter_matrix(dataset)
pt.show()

# %% [markdown]
# ## Evaluar algunos algoritmos
#
# Ahora es el momento de crear algunos modelos de los datos y estimar su precisión sobre los datos que no se pueden percibir.
#
# Esto es lo que vamos a cubrir en este paso:
# * Separar un conjunto de datos de validación.
# * Configurar las pruebas para usar una validación cruzada 10 veces.
# * Construir varios modelos diferentes para predecir especies a partir de mediciones de flores
# * Seleccionar el mejor modelo.

# %% [markdown]
# ## Crear un conjunto de datos de validación
#
# Necesitamos saber que el modelo que creamos es bueno.
#
# Posteriormente, utilizaremos métodos estadísticos para estimar la precisión de los modelos que creamos con datos que no conoce.
#
# También queremos una estimación más concreta de la precisión del mejor modelo en datos no conocidos evaluándolo en datos reales no vistos.
#
# Es decir, vamos a retener algunos datos que los algoritmos no podrán ver y usaremos estos datos para tener una segunda idea independiente de cuán preciso podría ser realmente el mejor modelo.

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC

# %%
# Split-out validation dataset
array = dataset.values
X = array[:,0:4]
y = array[:,4]
X_train, X_validation, Y_train, Y_validation = train_test_split(X, y, test_size=0.20, random_state=1)

# %% [markdown]
# Para obtener un poco más información sobre la técnica [k-fold cross-validation](https://machinelearningmastery.com/k-fold-cross-validation/)...
#
#
# Establecemos la semilla aleatoria mediante el argumento random_state en un número fijo para garantizar que cada algoritmo se evalúe en las mismas divisiones del conjunto de datos de entrenamiento.

# %% [markdown]
# ## Construir modelos
#
# No sabemos qué algoritmos serían buenos para este problema o qué configuraciones usar.
#
# Tenemos una idea de las gráficas de que algunas de las clases son parcialmente separables linealmente en algunas dimensiones, por lo que esperamos buenos resultados en general.
#
# Probemos algunos algoritmos diferentes:
#
#     Regresión logística (LR)
#     Análisis discriminante lineal (LDA)
#     K-Vecinos más cercanos (KNN).
#     Árboles de clasificación y regresión (CART).
#     Bayes ingenuo gaussiano (NB).
#     Soporta máquinas vectoriales (SVM).

# %%
# Spot Check Algorithms
models = []
models.append(('LR', LogisticRegression(solver='liblinear', multi_class='ovr')))
models.append(('LDA', LinearDiscriminantAnalysis()))
models.append(('KNN', KNeighborsClassifier()))
models.append(('CART', DecisionTreeClassifier()))
models.append(('NB', GaussianNB()))
models.append(('SVM', SVC(gamma='auto')))
# evaluate each model in turn
results = []
names = []
for name, model in models:
	kfold = StratifiedKFold(n_splits=10, random_state=1, shuffle=True)
	cv_results = cross_val_score(model, X_train, Y_train, cv=kfold, scoring='accuracy')
	results.append(cv_results)
	names.append(name)
	print('%s: %f (%f)' % (name, cv_results.mean(), cv_results.std()))
# Out:
# LR: 0.941667 (0.065085)
# LDA: 0.975000 (0.038188)
# KNN: 0.958333 (0.041667)
# CART: 0.958333 (0.041667)
# NB: 0.950000 (0.055277)
# SVM: 0.983333 (0.033333)

# %% [markdown]
# Una forma útil de comparar las muestras de resultados para cada algoritmo es crear un diagrama de caja y bigotes para cada distribución y comparar las distribuciones.

# %%
# Compare Algorithms
pt.boxplot(results, labels=names)
pt.title('Algorithm Comparison')
pt.show()

# %% [markdown]
# Podemos ver que los diagramas de caja y bigotes están aplastados en la parte superior del rango, con muchas evaluaciones que alcanzan el 100% de precisión y algunas muestran resultados hacia abajo oscilando en un 80% de precisión.

# %%
from pandas import read_csv
from matplotlib import pyplot
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
# Load dataset
url = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/iris.csv"
names = ['sepal-length', 'sepal-width', 'petal-length', 'petal-width', 'class']
dataset = read_csv(url, names=names)
# Split-out validation dataset
array = dataset.values
X = array[:,0:4]
y = array[:,4]
X_train, X_validation, Y_train, Y_validation = train_test_split(X, y, test_size=0.20, random_state=1, shuffle=True)
# Spot Check Algorithms
models = []
models.append(('LR', LogisticRegression(solver='liblinear', multi_class='ovr')))
models.append(('LDA', LinearDiscriminantAnalysis()))
models.append(('KNN', KNeighborsClassifier()))
models.append(('CART', DecisionTreeClassifier()))
models.append(('NB', GaussianNB()))
models.append(('SVM', SVC(gamma='auto')))
# evaluate each model in turn
results = []
names = []
for name, model in models:
	kfold = StratifiedKFold(n_splits=10, random_state=1, shuffle=True)
	cv_results = cross_val_score(model, X_train, Y_train, cv=kfold, scoring='accuracy')
	results.append(cv_results)
	names.append(name)
	print('%s: %f (%f)' % (name, cv_results.mean(), cv_results.std()))
# Compare Algorithms
pyplot.boxplot(results, labels=names)
pyplot.title('Algorithm Comparison')
pyplot.show()
# Out:
# LR: 0.941667 (0.065085)
# LDA: 0.975000 (0.038188)
# KNN: 0.958333 (0.041667)
# CART: 0.958333 (0.041667)
# NB: 0.950000 (0.055277)
# SVM: 0.983333 (0.033333)

# %% [markdown]
# ## Hacer predicciones
#
# Debemos elegir un algoritmo para hacer predicciones.
#
# Los resultados de la sección anterior sugieren que el SVM fue quizás el modelo más preciso. Usaremos este modelo como nuestro modelo final.
#
# Ahora queremos tener una idea de la precisión del modelo en nuestro conjunto de validación.
#
# Esto nos dará una verificación final independiente de la precisión del mejor modelo. Es valioso mantener un conjunto de validación por si acaso cometiste un desliz durante el entrenamiento, como un ajuste excesivo al conjunto de entrenamiento o una fuga de datos. Ambos problemas resultarán en un resultado demasiado optimista.

# %%
# Make predictions on validation dataset
model = SVC(gamma='auto')
model.fit(X_train, Y_train)
predictions = model.predict(X_validation)

# %% [markdown]
# ## Evaluar predicciones
#
# Podemos evaluar las predicciones comparándolas con los resultados esperados en el conjunto de validación, luego calcular la precisión de la clasificación, así como una matriz de confusión y un informe de clasificación.

# %%
# Evaluate predictions
print(accuracy_score(Y_validation, predictions))
print(confusion_matrix(Y_validation, predictions))
print(classification_report(Y_validation, predictions))
# Out:
# 0.9666666666666667
# [[11  0  0]
#  [ 0 12  1]
#  [ 0  0  6]]
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        11
# Iris-versicolor       1.00      0.92      0.96        13
#  Iris-virginica       0.86      1.00      0.92         6
#
#        accuracy                           0.97        30
#       macro avg       0.95      0.97      0.96        30
#    weighted avg       0.97      0.97      0.97        30

# %% [markdown]
# ## Aprendizaje automático supervisado
#
# En la mayoría de las aplicaciones de aprendizaje supervisado, el objetivo final es desarrollar una función de predicción `h(x)`  finamente ajustada (a veces denominada "hipótesis"). El *aprendizaje* consiste en el uso de algoritmos matemáticos `sofisticados` para optimizar esta función de modo que, dados los datos de entrada `x` sobre un determinado dominio (por ejemplo, pies cuadrados de una casa), predecirá con precisión algún valor interesante `h(x)` (por ejemplo, precio de mercado para dicha casa).

# %% [markdown]
# En la práctica, `x` casi siempre representa varios puntos de datos. Entonces, por ejemplo, un predictor del precio de la vivienda podría tomar no solo pies cuadrados (`x1`) sino también el número de dormitorios (`x2`), el número de baños (`x3`), el número de pisos (`x4`), el año de construcción (`x5`), el código postal (`x6`) y así sucesivamente.
#
# ---
#
# Determinar qué entradas usar es una parte importante del diseño de ML. Sin embargo, en aras de la explicación, es más fácil asumir que se utiliza un solo valor de entrada.
#
# $$h(X) = \theta_0 + \theta_1 x$$
#
# donde $\theta_0$ y $\theta_1$ son constantes. Nuestro objetivo es el encontrar los `valores perfectos`para $\theta_0$ y $\theta_1$ para hacer que nuestro predictor funcione de la mejor manera...
#
# ---
#
# La optimización de nuestro predictor $h(x)$ es a través de *ejemplos de entrenamiento*.
#
# Para cada ejemplo, tenemos una entrada $x_train$ con una salida correspondiente $y$, que es conocida por adelantado...
#
# ---
#
# Para cada ejemplo, encontramos la diferencia entre el valor correcto conocido `y` y nuestro valor predicho `h(x_train)`.
#
# Con suficientes ejemplos de entrenamiento, estas diferencias nos brindan una forma útil de medir la "incorrección" de $h(x)$. Entonces podemos modificar $h(x)$ ajustando los valores de $\theta_0$ y $\theta_1$  para que sea "menos erróneo".
#
# Este proceso se repite una y otra vez hasta que el sistema ha convergido en los mejores valores para $\theta_0$ y $\theta_1$ . De esta manera, el predictor se entrena y está listo para realizar algunas predicciones del mundo real.

# %% [markdown]
# ## Ejemplos de aprendizaje automático
#
# Nos ajustaremos ahorita a problemas simples (a pesar de que ya vimos algo *complicado* anteriormente...), pero la razón por la que existe ML es porque, en el mundo real, los problemas son mucho más complejos. En esta pantalla plana podemos dibujarle una imagen de, como máximo, un conjunto de datos tridimensionales, pero los problemas de aprendizaje automático normalmente tratan con datos con millones de dimensiones y funciones de predicción muy complejas. ML resuelve problemas que no se pueden resolver solo con medios numéricos.
